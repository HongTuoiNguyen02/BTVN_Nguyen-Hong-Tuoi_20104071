# %% [markdown]
# <a href="https://colab.research.google.com/github/HongTuoiNguyen02/BTVN_Nguyen-Hong-Tuoi_20104071/blob/main/Tu%E1%BA%A7n_4_%2B_3_B%C3%A0i_b%C3%A1o_(27_09_22).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 pip install scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 993 kB 20.9 MB/s
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894089 sha256=5cab739be8078b7b37792ddd3e2b15e657871e282da36e64ab1c2bc3e7d1536f
#   Stored in directory: /root/.cache/pip/wheels/d5/74/fc/38588a3d2e3f34f74588e6daa3aa5b0a322bd6f9420a707131
# Successfully built scikit-fuzzy
# ...

# %%
#PREDICTION OF RAINFALL USING FUZZY LOGIC
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

wind=ctrl.Antecedent(np.arange(0.7,3.1,0.1),'wind')
temp=ctrl.Antecedent(np.arange(20.4, 41.2,0.1),'temp')
rain= ctrl.Consequent(np.arange(0.2,9.1,0.1),'rain')

wind['veryhigh']=fuzz.trimf(wind.universe,[0.7,0.7,1.5])
wind['high']=fuzz.trimf(wind.universe,[0.7,1.5,2])
wind['normal']=fuzz.trimf(wind.universe,[1.5,2,2.8])
wind['low']=fuzz.trimf(wind.universe,[2,2.8,3.1])
wind['verylow']=fuzz.trimf(wind.universe,[2.8,3.1,3.1])

temp['veryhigh']=fuzz.trimf(temp.universe,[20.4,20.4,24])
temp['high']=fuzz.trimf(temp.universe,[20.4,24,27.3])
temp['normal']=fuzz.trimf(temp.universe,[24,27.3,35])
temp['low']=fuzz.trimf(temp.universe,[27.3,35,41.2])
temp['verylow']=fuzz.trimf(temp.universe,[35,41.2,41.2])

rain['veryhigh']=fuzz.trimf(rain.universe,[0.2,1,2.5])
rain['high']=fuzz.trimf(rain.universe,[1,2.5,4.5])
rain['normal']=fuzz.trimf(rain.universe,[2.5,4.5,6.5])
rain['low']=fuzz.trimf(rain.universe,[4.5,6.5,8])
rain['verylow']=fuzz.trimf(rain.universe,[6.5,8,9.1])

rule1=ctrl.Rule(wind['veryhigh'] & temp['veryhigh'],rain['veryhigh'])
rule2=ctrl.Rule(wind['veryhigh'] & temp['high'],rain['high'])
rule3=ctrl.Rule(wind['veryhigh'] & temp['normal'],rain['normal'])
rule4=ctrl.Rule(wind['veryhigh'] & temp['low'],rain['low'])
rule5=ctrl.Rule(wind['veryhigh'] & temp['verylow'],rain['verylow'])

rule6=ctrl.Rule(wind['high'] & temp['veryhigh'],rain['veryhigh'])
rule7=ctrl.Rule(wind['high'] & temp['high'],rain['high'])
rule8=ctrl.Rule(wind['high'] & temp['normal'],rain['normal'])
rule9=ctrl.Rule(wind['high'] & temp['low'],rain['low'])
rule10=ctrl.Rule(wind['high'] & temp['verylow'],rain['verylow'])

rule11=ctrl.Rule(wind['normal'] & temp['veryhigh'],rain['veryhigh'])
rule12=ctrl.Rule(wind['normal'] & temp['high'],rain['high'])
rule13=ctrl.Rule(wind['normal'] & temp['normal'],rain['normal'])
rule14=ctrl.Rule(wind['normal'] & temp['low'],rain['low'])
rule15=ctrl.Rule(wind['normal'] & temp['verylow'],rain['verylow'])

rule16=ctrl.Rule(wind['low'] & temp['veryhigh'],rain['veryhigh'])
rule17=ctrl.Rule(wind['low'] & temp['high'],rain['high'])
rule18=ctrl.Rule(wind['low'] & temp['normal'],rain['normal'])
rule19=ctrl.Rule(wind['low'] & temp['low'],rain['low'])
rule20=ctrl.Rule(wind['low'] & temp['verylow'],rain['verylow'])

rule21=ctrl.Rule(wind['verylow'] & temp['veryhigh'],rain['veryhigh'])
rule22=ctrl.Rule(wind['verylow'] & temp['high'],rain['high'])
rule23=ctrl.Rule(wind['verylow'] & temp['normal'],rain['normal'])
rule24=ctrl.Rule(wind['verylow'] & temp['low'],rain['low'])
rule25=ctrl.Rule(wind['verylow'] & temp['verylow'],rain['verylow'])

rainfall_ctrl=ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9,rule10,rule11,rule12,rule13,rule14,rule15,rule16,rule17,rule18,rule19,rule20,rule21,rule22,rule23,rule24,rule25])
rainfall=ctrl.ControlSystemSimulation(rainfall_ctrl)
rainfall.input['wind']=30
rainfall.input['temp']=2.8
rainfall.compute()
print(rainfall.output["rain"])
rain.view(sim=rainfall)
# Out:
# 1.2333333333333334

# %%
#Adaptive Food Suggestion Engine by Fuzzy Logic
import numpy as np 
import skfuzzy as fuzz 
from skfuzzy import control as ctrl 

muivi = ctrl.Antecedent(np.arange(1,5,1), 'muivi')
moitruong = ctrl.Antecedent(np.arange(1,5,1), 'moitruong')
gia = ctrl.Antecedent(np.arange(0,81,1), 'gia')
dohailong = ctrl.Antecedent(np.arange(1,5,1), 'dohailong')
vitri = ctrl.Antecedent(np.arange(1,5,1), 'vitri')
douutien = ctrl.Consequent(np.arange(1,6,1), 'douutien')

muivi['thap']=fuzz.trimf(muivi.universe,[1,1,3])
muivi['vua']=fuzz.trimf(muivi.universe,[1,3,5])
muivi['cao']=fuzz.trimf(muivi.universe,[3,5,5])

moitruong['thap']=fuzz.trimf(moitruong.universe,[1,1,3])
moitruong['vua']=fuzz.trimf(moitruong.universe,[1,3,5])
moitruong['cao']=fuzz.trimf(moitruong.universe,[3,5,5])

gia['thap']=fuzz.trimf(gia.universe,[0,0,40])
gia['vua']=fuzz.trimf(gia.universe,[0,40,81])
gia['cao']=fuzz.trimf(gia.universe,[40,81,81])

dohailong['thap']=fuzz.trimf(dohailong.universe,[1,1,3])
dohailong['vua']=fuzz.trimf(dohailong.universe,[1,3,5])
dohailong['cao']=fuzz.trimf(dohailong.universe,[3,5,5])

vitri['xa']=fuzz.trimf(vitri.universe,[1,1,3])
vitri['vua']=fuzz.trimf(vitri.universe,[1,3,5])
vitri['gan']=fuzz.trimf(vitri.universe,[3,5,5])

douutien['cap1']=fuzz.trimf(douutien.universe,[1,1,2])
douutien['cap2']=fuzz.trimf(douutien.universe,[1,2,3])
douutien['cap3']=fuzz.trimf(douutien.universe,[2,3,4])
douutien['cap4']=fuzz.trimf(douutien.universe,[3,4,5])
douutien['cap5']=fuzz.trimf(douutien.universe,[4,5,5])

rule1 = ctrl.Rule(muivi['vua'] & moitruong['thap'] & gia['thap'] & dohailong['thap'] & vitri['xa'], douutien['cap2'])
rule2 = ctrl.Rule(muivi['vua'] & moitruong['thap'] & gia['thap'] & dohailong['thap'] & vitri['vua'], douutien['cap3'])
rule3 = ctrl.Rule(muivi['cao'] & moitruong['cao'] & gia['vua'] & dohailong['cao'] & vitri['vua'], douutien['cap5'])
rule4 = ctrl.Rule(muivi['cao'] & moitruong['cao'] & gia['vua'] & dohailong['cao'] & vitri['gan'], douutien['cap5'])
rule5 =  ctrl.Rule(muivi['vua'] & moitruong['thap'] & gia['thap'] & dohailong['thap'] & vitri['gan'], douutien['cap3'])

rule6 = ctrl.Rule(muivi['thap'] & moitruong['vua'] & gia['thap'] & dohailong['thap'] & vitri['gan'], douutien['cap3'])
rule7 = ctrl.Rule(muivi['thap'] & moitruong['cao'] & gia['thap'] & dohailong['thap'] & vitri['xa'], douutien['cap3'])
rule8 = ctrl.Rule(muivi['vua'] & moitruong['vua'] & gia['vua'] & dohailong['vua'] & vitri['gan'], douutien['cap4'])
rule9 = ctrl.Rule(muivi['vua'] & moitruong['thap'] & gia['thap'] & dohailong['thap'] & vitri['xa'], douutien['cap2'])
rule10 = ctrl.Rule(muivi['cao'] & moitruong['vua'] & gia['vua'] & dohailong['vua'] & vitri['xa'], douutien['cap4'])

rule11 =  ctrl.Rule(muivi['vua'] & moitruong['thap'] & gia['thap'] & dohailong['thap'] & vitri['vua'], douutien['cap2'])
rule12 = ctrl.Rule(muivi['cao'] & moitruong['cao'] & gia['cao'] & dohailong['vua'] & vitri['xa'], douutien['cap4'])
rule13 = ctrl.Rule(muivi['cao'] & moitruong['cao'] & gia['cao'] & dohailong['vua'] & vitri['vua'], douutien['cap5'])
rule14 = ctrl.Rule(muivi['vua'] & moitruong['vua'] & gia['thap'] & dohailong['thap'] & vitri['xa'], douutien['cap3'])
rule15 = ctrl.Rule(muivi['vua'] & moitruong['vua'] & gia['thap'] & dohailong['thap'] & vitri['vua'], douutien['cap3'])

rule16 = ctrl.Rule(muivi['thap'] & moitruong['vua'] & gia['thap'] & dohailong['thap'] & vitri['xa'], douutien['cap2'])
rule17= ctrl.Rule(muivi['thap'] & moitruong['vua'] & gia['thap'] & dohailong['thap'] & vitri['vua'], douutien['cap2'])
rule18 = ctrl.Rule(muivi['vua'] & moitruong['vua'] & gia['thap'] & dohailong['thap'] & vitri['gan'], douutien['cap3'])
rule19 = ctrl.Rule(muivi['cao'] & moitruong['cao'] & gia['cao'] & dohailong['cao'] & vitri['vua'], douutien['cap5'])
rule20 = ctrl.Rule(muivi['cao'] & moitruong['cao'] & gia['cao'] & dohailong['cao'] & vitri['gan'], douutien['cap5'])

rule21 = ctrl.Rule(muivi['vua'] & moitruong['cao'] & gia['thap'] & dohailong['thap'] & vitri['gan'], douutien['cap4'])
rule22 = ctrl.Rule(muivi['cao'] & moitruong['thap'] & gia['thap'] & dohailong['thap'] & vitri['xa'], douutien['cap3'])
rule23 = ctrl.Rule(muivi['cao'] & moitruong['thap'] & gia['thap'] & dohailong['thap'] & vitri['gan'], douutien['cap3'])
rule24 = ctrl.Rule(muivi['cao'] & moitruong['vua'] & gia['vua'] & dohailong['vua'] & vitri['gan'], douutien['cap4'])
rule25 = ctrl.Rule(muivi['cao'] & moitruong['vua'] & gia['thap'] & dohailong['thap'] & vitri['xa'], douutien['cap3'])

rule26 = ctrl.Rule(muivi['cao'] & moitruong['cao'] & gia['vua'] & dohailong['cao'] & vitri['xa'], douutien['cap4'])
rule27 = ctrl.Rule(muivi['cao'] & moitruong['cao'] & gia['thap'] & dohailong['thap'] & vitri['xa'], douutien['cap3'])
rule28 = ctrl.Rule(muivi['vua'] & moitruong['thap'] & gia['vua'] & dohailong['vua'] & vitri['gan'], douutien['cap4'])
rule29 = ctrl.Rule(muivi['cao'] & moitruong['thap'] & gia['vua'] & dohailong['vua'] & vitri['xa'], douutien['cap3'])
rule30 = ctrl.Rule(muivi['cao'] & moitruong['cao'] & gia['thap'] & dohailong['thap'] & vitri['vua'], douutien['cap4'])

rule31 = ctrl.Rule(muivi['cao'] & moitruong['cao'] & gia['thap'] & dohailong['thap'] & vitri['gan'], douutien['cap4'])
rule32 = ctrl.Rule(muivi['cao'] & moitruong['vua'] & gia['thap'] & dohailong['thap'] & vitri['vua'], douutien['cap3'])
rule33 = ctrl.Rule(muivi['cao'] & moitruong['vua'] & gia['thap'] & dohailong['thap'] & vitri['gan'], douutien['cap4'])
rule34 = ctrl.Rule(muivi['vua'] & moitruong['thap'] & gia['thap'] & dohailong['thap'] & vitri['gan'], douutien['cap3'])
rule35 = ctrl.Rule(muivi['vua'] & moitruong['thap'] & gia['vua'] & dohailong['vua'] & vitri['xa'], douutien['cap3'])

rule36 = ctrl.Rule(muivi['vua'] & moitruong['thap'] & gia['vua'] & dohailong['vua'] & vitri['vua'], douutien['cap3'])
rule37 = ctrl.Rule(muivi['vua'] & moitruong['vua'] & gia['vua'] & dohailong['vua'] & vitri['xa'], douutien['cap3'])
rule38 = ctrl.Rule(muivi['cao'] & moitruong['thap'] & gia['vua'] & dohailong['vua'] & vitri['vua'], douutien['cap4'])
rule39 = ctrl.Rule(muivi['cao'] & moitruong['thap'] & gia['vua'] & dohailong['vua'] & vitri['gan'], douutien['cap4'])
rule40 = ctrl.Rule(muivi['cao'] & moitruong['cao'] & gia['vua'] & dohailong['vua'] & vitri['xa'], douutien['cap4'])

rule41 = ctrl.Rule(muivi['cao'] & moitruong['cao'] & gia['vua'] & dohailong['vua'] & vitri['vua'], douutien['cap4'])
rule42 = ctrl.Rule(muivi['vua'] & moitruong['cao'] & gia['thap'] & dohailong['thap'] & vitri['xa'], douutien['cap3'])
rule43 = ctrl.Rule(muivi['vua'] & moitruong['cao'] & gia['thap'] & dohailong['thap'] & vitri['vua'], douutien['cap3'])
rule44 = ctrl.Rule(muivi['cao'] & moitruong['cao'] & gia['vua'] & dohailong['vua'] & vitri['gan'], douutien['cap5'])
rule45 = ctrl.Rule(muivi['thap'] & moitruong['cao'] & gia['thap'] & dohailong['thap'] & vitri['vua'], douutien['cap3'])

rule46 = ctrl.Rule(muivi['thap'] & moitruong['cao'] & gia['thap'] & dohailong['thap'] & vitri['gan'], douutien['cap3'])
rule47 = ctrl.Rule(muivi['cao'] & moitruong['cao'] & gia['cao'] & dohailong['vua'] & vitri['gan'], douutien['cap5'])
rule48 = ctrl.Rule(muivi['cao'] & moitruong['cao'] & gia['cao'] & dohailong['cao'] & vitri['xa'], douutien['cap5'])
rule49 = ctrl.Rule(muivi['vua'] & moitruong['vua'] & gia['vua'] & dohailong['vua'] & vitri['vua'], douutien['cap4'])
rule50 = ctrl.Rule(muivi['cao'] & moitruong['vua'] & gia['vua'] & dohailong['vua'] & vitri['vua'], douutien['cap4'])

rule51 = ctrl.Rule(muivi['thap'] & moitruong['thap'] & gia['thap'] & dohailong['thap'] & vitri['vua'], douutien['cap2'])
rule52 = ctrl.Rule(muivi['cao'] & moitruong['thap'] & gia['thap'] & dohailong['thap'] & vitri['vua'], douutien['cap3'])

doan_ctrl = ctrl.ControlSystem([rule1, rule2, rule3, rule4, rule5, rule6, rule7, rule8, rule9,rule10,rule11,rule12,rule13,rule14,rule15,rule16,rule17,rule18,rule19,rule20,rule21,rule22,rule23,rule24,rule25,rule26,rule27,rule28,rule29,rule30,rule31,rule32,rule33,rule34,rule35,rule36,rule37,rule38,rule39,rule40,rule41,rule42,rule43,rule44,rule45,rule46,rule47,rule48,rule49,rule50,rule51,rule52])
doan = ctrl.ControlSystemSimulation(doan_ctrl)
doan.input['muivi'] = 4
doan.input['moitruong'] = 2
doan.input['gia'] = 50
doan.input['dohailong'] = 3
doan.input['vitri'] = 2
doan.compute()
print (doan.output['douutien'])
douutien.view(sim=doan)
# Out:
# 3.5

# %%
#Intelligent Size Matching Recommender System: Fuzzy Logic Approach in Children Clothing Selection
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

chieucao = ctrl.Antecedent(np.arange(110,160,10), 'chieucao')
cannang = ctrl.Antecedent(np.arange(18,35,1), 'cannang')
vongnguc = ctrl.Antecedent(np.arange(50,70,10), 'vongnguc')
thatlung = ctrl.Antecedent(np.arange(50,70,10), 'thatlung')
kichco = ctrl.Consequent(np.arange(5,16,1), 'kichco')

chieucao['thap']=fuzz.trimf(chieucao.universe,[110,110,140])
chieucao['vua']=fuzz.trimf(chieucao.universe,[110,140,160])
chieucao['cao']=fuzz.trimf(chieucao.universe,[140,160,160])

cannang['om']=fuzz.trimf(cannang.universe,[18,18,25])
cannang['vua']=fuzz.trimf(cannang.universe,[18,25,35])
cannang['map']=fuzz.trimf(cannang.universe,[25,35,35])

vongnguc['nho']=fuzz.trimf(vongnguc.universe,[50,50,60])
vongnguc['vua']=fuzz.trimf(vongnguc.universe,[50,60,70])
vongnguc['to']=fuzz.trimf(vongnguc.universe,[60,70,70])

thatlung['nho']=fuzz.trimf(thatlung.universe,[50,50,50])
thatlung['vua']=fuzz.trimf(thatlung.universe,[50,60,70])
thatlung['rong']=fuzz.trimf(thatlung.universe,[60,70,70])

kichco['nho']=fuzz.trimf(kichco.universe,[5,5,9])
kichco['vua']=fuzz.trimf(kichco.universe,[5,9,16])
kichco['to']=fuzz.trimf(kichco.universe,[9,16,16])

rule1 = ctrl.Rule(chieucao['thap'] & cannang['om'] & vongnguc['nho'] & thatlung['nho'] , kichco['nho'])
rule2 = ctrl.Rule(chieucao['vua'] & cannang['vua'] & vongnguc['vua'] & thatlung['vua'] , kichco['vua'])
rule3 = ctrl.Rule(chieucao['cao'] & cannang['map'] & vongnguc['to'] & thatlung['rong'] , kichco['to'])
rule4 = ctrl.Rule(chieucao['thap'] & cannang['vua'] & vongnguc['vua'] & thatlung['vua'] ,kichco['vua'])
rule5 = ctrl.Rule(chieucao['thap'] & cannang['map'] & vongnguc['to'] & thatlung['rong'] , kichco['to'])

rule6 = ctrl.Rule(chieucao['vua'] & cannang['om'] & vongnguc['nho'] & thatlung['nho'] , kichco['nho'])
rule7 = ctrl.Rule(chieucao['vua'] & cannang['map'] & vongnguc['to'] & thatlung['rong'] , kichco['to'])
rule8 = ctrl.Rule(chieucao['cao'] & cannang['vua'] & vongnguc['vua'] & thatlung['vua'] , kichco['vua'])
rule9 = ctrl.Rule(chieucao['thap'] & cannang['om'] & vongnguc['vua'] & thatlung['vua'] , kichco['nho'])
rule10 = ctrl.Rule(chieucao['cao'] & cannang['map'] & vongnguc['nho'] & thatlung['nho'] , kichco['vua'])

rule11 = ctrl.Rule(chieucao['cao'] & cannang['map'] & vongnguc['vua'] & thatlung['vua'] , kichco['to'])
rule12 = ctrl.Rule(chieucao['thap'] & cannang['om'] & vongnguc['nho'] & thatlung['vua'] , kichco['nho'])
rule13 = ctrl.Rule(chieucao['thap'] & cannang['om'] & vongnguc['nho'] & thatlung['rong'] , kichco['nho'])
rule14 = ctrl.Rule(chieucao['vua'] & cannang['vua'] & vongnguc['vua'] & thatlung['nho'] , kichco['vua'])
rule15 = ctrl.Rule(chieucao['vua'] & cannang['vua'] & vongnguc['vua'] & thatlung['rong'] , kichco['vua'])

rule16 = ctrl.Rule(chieucao['cao'] & cannang['map'] & vongnguc['to'] & thatlung['nho'] , kichco['to'])
rule17 = ctrl.Rule(chieucao['cao'] & cannang['map'] & vongnguc['to'] & thatlung['vua'] , kichco['to'])
rule18 = ctrl.Rule(chieucao['thap'] & cannang['vua'] & vongnguc['nho'] & thatlung['nho'] , kichco['nho'])
rule19 = ctrl.Rule(chieucao['thap'] & cannang['vua'] & vongnguc['to'] & thatlung['rong'] , kichco['vua'])
rule20 = ctrl.Rule(chieucao['thap'] & cannang['map'] & vongnguc['nho'] & thatlung['nho'] , kichco['nho'])

rule21 = ctrl.Rule(chieucao['thap'] & cannang['map'] & vongnguc['vua'] & thatlung['vua'] , kichco['vua'])
rule22 = ctrl.Rule(chieucao['vua'] & cannang['om'] & vongnguc['vua'] & thatlung['vua'] , kichco['vua'])
rule23 = ctrl.Rule(chieucao['vua'] & cannang['om'] & vongnguc['to'] & thatlung['rong'] , kichco['vua'])
rule24 = ctrl.Rule(chieucao['vua'] & cannang['map'] & vongnguc['vua'] & thatlung['vua'] , kichco['vua'])
rule25 = ctrl.Rule(chieucao['vua'] & cannang['map'] & vongnguc['nho'] & thatlung['nho'] , kichco['to'])

rule26 = ctrl.Rule(chieucao['cao'] & cannang['om'] & vongnguc['vua'] & thatlung['vua'] , kichco['vua'])
rule27 = ctrl.Rule(chieucao['cao'] & cannang['om'] & vongnguc['to'] & thatlung['rong'] , kichco['to'])
rule28 = ctrl.Rule(chieucao['cao'] & cannang['vua'] & vongnguc['nho'] & thatlung['nho'] , kichco['nho'])
rule29 = ctrl.Rule(chieucao['cao'] & cannang['vua'] & vongnguc['to'] & thatlung['rong'] , kichco['to'])
rule30 = ctrl.Rule(chieucao['thap'] & cannang['vua'] & vongnguc['vua'] & thatlung['nho'] , kichco['nho'])

rule31 = ctrl.Rule(chieucao['thap'] & cannang['vua'] & vongnguc['vua'] & thatlung['rong'] , kichco['nho'])
rule32 = ctrl.Rule(chieucao['thap'] & cannang['map'] & vongnguc['to'] & thatlung['nho'] , kichco['vua'])
rule33 = ctrl.Rule(chieucao['thap'] & cannang['map'] & vongnguc['to'] & thatlung['rong'] , kichco['vua'])
rule34 = ctrl.Rule(chieucao['vua'] & cannang['om'] & vongnguc['nho'] & thatlung['vua'] , kichco['nho'])
rule35 = ctrl.Rule(chieucao['vua'] & cannang['om'] & vongnguc['nho'] & thatlung['rong'] , kichco['nho'])

rule36 = ctrl.Rule(chieucao['vua'] & cannang['map'] & vongnguc['to'] & thatlung['nho'] , kichco['vua'])
rule37 = ctrl.Rule(chieucao['cao'] & cannang['om'] & vongnguc['nho'] & thatlung['rong'] , kichco['nho'])
rule38 = ctrl.Rule(chieucao['cao'] & cannang['om'] & vongnguc['nho'] & thatlung['vua'] , kichco['nho'])
rule39 = ctrl.Rule(chieucao['vua'] & cannang['map'] & vongnguc['to'] & thatlung['vua'] , kichco['vua'])
rule40 = ctrl.Rule(chieucao['cao'] & cannang['vua'] & vongnguc['vua'] & thatlung['nho'] , kichco['vua'])

rule41 = ctrl.Rule(chieucao['cao'] & cannang['vua'] & vongnguc['vua'] & thatlung['rong'] , kichco['vua'])
rule42 = ctrl.Rule(chieucao['thap'] & cannang['vua'] & vongnguc['nho'] & thatlung['rong'] , kichco['vua'])
rule43 = ctrl.Rule(chieucao['thap'] & cannang['map'] & vongnguc['nho'] & thatlung['rong'] , kichco['vua'])
rule44 = ctrl.Rule(chieucao['vua'] & cannang['om'] & vongnguc['to'] & thatlung['nho'] , kichco['vua'])
rule45 = ctrl.Rule(chieucao['vua'] & cannang['map'] & vongnguc['nho'] & thatlung['rong'] , kichco['to'])

size_ctrl = ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9,rule10,rule11,rule12,rule13,rule14,rule15,rule16,rule17,rule18,rule19,rule20,rule21,rule22,rule23,rule24,rule25,rule26,rule27,rule28,rule29,rule30,rule31,rule32,rule33,rule34,rule35,rule36,rule37,rule38,rule39,rule40,rule41,rule42,rule43,rule44,rule45])
size= ctrl.ControlSystemSimulation(size_ctrl)
size.input['chieucao'] = 156
size.input['cannang'] = 30
size.input['vongnguc'] = 40
size.input['thatlung'] = 50
size.compute()
print (size.output['kichco'])
kichco.view(sim=size)
# Out:
# 10.0

# %%
#Medical Diagnosis System Using Fuzzy Logic 
import numpy as np 
import skfuzzy as fuzz 
from skfuzzy import control as ctrl 


sot = ctrl.Antecedent(np.arange(0,5,0.5), 'sot')
daudau = ctrl.Antecedent(np.arange(0,5,0.5), 'daudau')
buonnon = ctrl.Antecedent(np.arange(0,5,0.5), 'buonnon')
nonmua = ctrl.Antecedent(np.arange(0,5,0.5), 'nonmua')
vangda = ctrl.Antecedent(np.arange(0,5,0.5), 'vangda')
gan = ctrl.Antecedent(np.arange(0,5,0.5), 'gan')
daukhop = ctrl.Antecedent(np.arange(0,5,0.5), 'daukhop')
suynhuoccothe = ctrl.Antecedent(np.arange(0,5,0.5), 'suynhuoccothe')
chongmat = ctrl.Antecedent(np.arange(0,5,0.5), 'chongmat')
lacmieng = ctrl.Antecedent(np.arange(0,5,0.5), 'lacmieng')
MP = ctrl.Antecedent(np.arange(0,5,0.5), 'MP')
conclusion = ctrl.Consequent(np.arange(0,5,0.5), 'conclusion')

sot['nhe']=fuzz.trimf(sot.universe,[0,0,1])
sot['vua']=fuzz.trimf(sot.universe,[0,1,3])
sot['nang']=fuzz.trimf(sot.universe,[1,3,5])
sot['ratnang']=fuzz.trimf(sot.universe,[3,5,5])

daudau['nhe']=fuzz.trimf(daudau.universe,[0,0,1])
daudau['vua']=fuzz.trimf(daudau.universe,[0,1,3])
daudau['nang']=fuzz.trimf(daudau.universe,[1,3,5])
daudau['ratnang']=fuzz.trimf(daudau.universe,[3,5,5])

buonnon['nhe']=fuzz.trimf(buonnon.universe,[0,0,1])
buonnon['vua']=fuzz.trimf(buonnon.universe,[0,1,3])
buonnon['nang']=fuzz.trimf(buonnon.universe,[1,3,5])
buonnon['ratnang']=fuzz.trimf(buonnon.universe,[3,5,5])

nonmua['nhe']=fuzz.trimf(nonmua.universe,[0,0,1])
nonmua['vua']=fuzz.trimf(nonmua.universe,[0,1,3])
nonmua['nang']=fuzz.trimf(nonmua.universe,[1,3,5])
nonmua['ratnang']=fuzz.trimf(nonmua.universe,[3,5,5])

vangda['nhe']=fuzz.trimf(vangda.universe,[0,0,1])
vangda['vua']=fuzz.trimf(vangda.universe,[0,1,3])
vangda['nang']=fuzz.trimf(vangda.universe,[1,3,5])
vangda['ratnang']=fuzz.trimf(vangda.universe,[3,5,5])

gan['nhe']=fuzz.trimf(gan.universe,[0,0,1])
gan['vua']=fuzz.trimf(gan.universe,[0,1,3])
gan['nang']=fuzz.trimf(gan.universe,[1,3,5])
gan['ratnang']=fuzz.trimf(gan.universe,[3,5,5])

daukhop['nhe']=fuzz.trimf(daukhop.universe,[0,0,1])
daukhop['vua']=fuzz.trimf(daukhop.universe,[0,1,3])
daukhop['nang']=fuzz.trimf(daukhop.universe,[1,3,5])
daukhop['ratnang']=fuzz.trimf(daukhop.universe,[3,5,5])

suynhuoccothe['nhe']=fuzz.trimf(suynhuoccothe.universe,[0,0,1])
suynhuoccothe['vua']=fuzz.trimf(suynhuoccothe.universe,[0,1,3])
suynhuoccothe['nang']=fuzz.trimf(suynhuoccothe.universe,[1,3,5])
suynhuoccothe['ratnang']=fuzz.trimf(suynhuoccothe.universe,[3,5,5])

chongmat['nhe']=fuzz.trimf(chongmat.universe,[0,0,1])
chongmat['vua']=fuzz.trimf(chongmat.universe,[0,1,3])
chongmat['nang']=fuzz.trimf(chongmat.universe,[1,3,5])
chongmat['ratnang']=fuzz.trimf(chongmat.universe,[3,5,5])

lacmieng['nhe']=fuzz.trimf(lacmieng.universe,[0,0,1])
lacmieng['vua']=fuzz.trimf(lacmieng.universe,[0,1,3])
lacmieng['nang']=fuzz.trimf(lacmieng.universe,[1,3,5])
lacmieng['ratnang']=fuzz.trimf(lacmieng.universe,[3,5,5])

MP['nhe']=fuzz.trimf(MP.universe,[0,0,1])
MP['vua']=fuzz.trimf(MP.universe,[0,1,3])
MP['nang']=fuzz.trimf(MP.universe,[1,3,5])
MP['ratnang']=fuzz.trimf(MP.universe,[3,5,5])

conclusion['nhe']=fuzz.trimf(conclusion.universe,[0,0,1])
conclusion['vua']=fuzz.trimf(conclusion.universe,[0,1,3])
conclusion['nang']=fuzz.trimf(conclusion.universe,[1,3,5])
conclusion['ratnang']=fuzz.trimf(conclusion.universe,[3,5,5])

rule1 = ctrl.Rule(sot['nhe'] & daudau['nhe'] & buonnon['nhe'] & nonmua['nhe'] & vangda['nhe'] & gan['nhe'] & daukhop['nhe'] & suynhuoccothe['nhe'] & chongmat['nang'] & lacmieng['nhe'] & MP['nhe'], conclusion['nhe'])
rule2 = ctrl.Rule(sot['vua'] & daudau['nhe'] & buonnon['nhe'] & nonmua['nhe'] & vangda['nhe'] & gan['nhe'] & daukhop['vua'] & suynhuoccothe['vua'] & chongmat['nang'] & lacmieng['nang'] & MP['vua'], conclusion['vua'])
rule3 = ctrl.Rule(sot['nang'] & daudau['vua'] & buonnon['nhe'] & nonmua['nhe'] & vangda['nhe'] & gan['nhe'] & daukhop['nhe'] & suynhuoccothe['nang'] & chongmat['nang'] & lacmieng['nang'] & MP['vua'], conclusion['nhe'])
rule4 = ctrl.Rule(sot['ratnang'] & daudau['nhe'] & buonnon['nhe'] & nonmua['nhe'] & vangda['nhe'] & gan['nhe'] & daukhop['nang'] & suynhuoccothe['nang'] & chongmat['nhe'] & lacmieng['nhe'] & MP['nang'],  conclusion['ratnang'])
rule5 = ctrl.Rule(sot['vua'] & daudau['nhe'] & buonnon['nhe'] & nonmua['vua'] & vangda['nhe'] & gan['nhe'] & daukhop['vua'] & suynhuoccothe['vua'] & chongmat['vua'] & lacmieng['nang'] & MP['vua'], conclusion['vua'])

rule6 = ctrl.Rule(sot['nhe'] & daudau['vua'] & buonnon['vua'] & nonmua['nhe'] & vangda['nhe'] & gan['nhe'] & daukhop['nhe'] & suynhuoccothe['nhe'] & chongmat['vua'] & lacmieng['nhe'] & MP['nhe'], conclusion['nhe'])
rule7 = ctrl.Rule(sot['nhe'] & daudau['nhe'] & buonnon['vua'] & nonmua['vua'] & vangda['nhe'] & gan['nhe'] & daukhop['nang'] & suynhuoccothe['nang'] & chongmat['vua'] & lacmieng['vua'] & MP['vua'], conclusion['nang'])
rule8 = ctrl.Rule(sot['vua'] & daudau['vua'] & buonnon['vua'] & nonmua['vua'] & vangda['vua'] & gan['vua'] & daukhop['vua'] & suynhuoccothe['vua'] & chongmat['vua'] & lacmieng['vua'] & MP['vua'], conclusion['vua'])
rule9 = ctrl.Rule(sot['vua'] & daudau['nhe'] & buonnon['vua'] & nonmua['vua'] & vangda['nhe'] & gan['nang'] & daukhop['vua'] & suynhuoccothe['vua'] & chongmat['nang'] & lacmieng['vua'] & MP['vua'], conclusion['vua'])
rule10 = ctrl.Rule(sot['nhe'] & daudau['nhe'] & buonnon['vua'] & nonmua['vua'] & vangda['nhe'] & gan['vua'] & daukhop['nhe'] & suynhuoccothe['nhe'] & chongmat['nhe'] & lacmieng['nhe'] & MP['nhe'], conclusion['nhe'])

rule11 =  ctrl.Rule(sot['nang'] & daudau['nang'] & buonnon['nang'] & nonmua['nang'] & vangda['nang'] & gan['nang'] & daukhop['nang'] & suynhuoccothe['ratnang'] & chongmat['nang'] & lacmieng['nang'] & MP['vua'], conclusion['ratnang'])
rule12 =  ctrl.Rule(sot['vua'] & daudau['nang'] & buonnon['vua'] & nonmua['nang'] & vangda['vua'] & gan['nang'] & daukhop['vua'] & suynhuoccothe['nang'] & chongmat['vua'] & lacmieng['nhe'] & MP['vua'], conclusion['nang'])
rule13 = ctrl.Rule(sot['nhe'] & daudau['vua'] & buonnon['vua'] & nonmua['vua'] & vangda['nhe'] & gan['nhe'] & daukhop['nhe'] & suynhuoccothe['vua'] & chongmat['nhe'] & lacmieng['vua'] & MP['vua'], conclusion['vua'])
rule14 = ctrl.Rule(sot['nang'] & daudau['nang'] & buonnon['vua'] & nonmua['nang'] & vangda['nang'] & gan['nang'] & daukhop['nang'] & suynhuoccothe['nang'] & chongmat['vua'] & lacmieng['vua'] & MP['nang'], conclusion['nang'])
rule15 = ctrl.Rule(sot['nhe'] & daudau['nhe'] & buonnon['nhe'] & nonmua['vua'] & vangda['nhe'] & gan['nhe'] & daukhop['nhe'] & suynhuoccothe['nang'] & chongmat['nhe'] & lacmieng['nang'] & MP['vua'], conclusion['nang'])

rule16 = ctrl.Rule(sot['ratnang'] & daudau['vua'] & buonnon['nhe'] & nonmua['vua'] & vangda['nang'] & gan['vua'] & daukhop['nhe'] & suynhuoccothe['ratnang'] & chongmat['nang'] & lacmieng['nhe'] & MP['vua'], conclusion['ratnang'])
rule17 = ctrl.Rule(sot['nhe'] & daudau['ratnang'] & buonnon['vua'] & nonmua['vua'] & vangda['nhe'] & gan['vua'] & daukhop['nhe'] & suynhuoccothe['vua'] & chongmat['ratnang'] & lacmieng['nhe'] & MP['vua'], conclusion['ratnang'])
rule18 = ctrl.Rule(sot['vua'] & daudau['ratnang'] & buonnon['ratnang'] & nonmua['nhe'] & vangda['nang'] & gan['nang'] & daukhop['vua'] & suynhuoccothe['nang'] & chongmat['ratnang'] & lacmieng['ratnang'] & MP['nang'], conclusion['ratnang'])
rule19 = ctrl.Rule(sot['vua'] & daudau['vua'] & buonnon['vua'] & nonmua['vua'] & vangda['nhe'] & gan['nhe'] & daukhop['vua'] & suynhuoccothe['vua'] & chongmat['vua'] & lacmieng['vua'] & MP['vua'], conclusion['vua'])
rule20 = ctrl.Rule(sot['ratnang'] & daudau['nang'] & buonnon['nang'] & nonmua['nang'] & vangda['nang'] & gan['nang'] & daukhop['nang'] & suynhuoccothe['nang'] & chongmat['nang'] & lacmieng['nang'] & MP['vua'], conclusion['ratnang'])

ketqua_ctrl = ctrl.ControlSystem([rule1, rule2, rule3, rule4, rule5, rule6, rule7, rule8, rule8, rule9,rule10,rule11,rule12,rule13,rule14,rule15,rule16,rule17,rule18,rule19,rule20])
ketqua = ctrl.ControlSystemSimulation(ketqua_ctrl)
ketqua.input['sot'] = 2
ketqua.input['daudau'] = 2
ketqua.input['buonnon'] = 2
ketqua.input['nonmua'] = 2
ketqua.input['vangda'] = 1
ketqua.input['gan'] = 1
ketqua.input['daukhop'] = 2
ketqua.input['suynhuoccothe'] = 2
ketqua.input['chongmat'] = 2
ketqua.input['lacmieng'] = 2
ketqua.input['MP'] = 2
ketqua.compute()
print (ketqua.output['conclusion'])
conclusion.view(sim=ketqua)
# Out:
# 1.3888888888888888

# %%
#Nutritional Needs Recommendation Based on Fuzzy Logic
#CALO
import numpy as np 
import skfuzzy as fuzz 
from skfuzzy import control as ctrl 
chieucao = ctrl.Antecedent(np.arange(120,181,1), 'chieucao')
cannang = ctrl.Antecedent(np.arange(15,80,1), 'cannang')
gioitinh = ctrl.Antecedent(np.arange(1,3,1), 'gioitinh')
tuoi = ctrl.Antecedent(np.arange(0,101,1), 'tuoi')
calo = ctrl.Consequent(np.arange(0,1700,100), 'calo')

chieucao['thap']=fuzz.trimf(chieucao.universe,[120,120,150])
chieucao['TB']=fuzz.trimf(chieucao.universe,[120,150,181])
chieucao['cao']=fuzz.trimf(chieucao.universe,[150,181,181])

cannang['nhe']=fuzz.trimf(cannang.universe,[15,15,45])
cannang['TB']=fuzz.trimf(cannang.universe,[15,45,80])
cannang['nang']=fuzz.trimf(cannang.universe,[45,80,80])

gioitinh['nu']=fuzz.trimf(gioitinh.universe,[1,1,2])
gioitinh['nam']=fuzz.trimf(gioitinh.universe,[1,2,3])

tuoi['thanhnien']=fuzz.trimf(tuoi.universe,[0,0,30])
tuoi['trungnien']=fuzz.trimf(tuoi.universe,[0,30,60])
tuoi['caonien']=fuzz.trimf(tuoi.universe,[60,101,101])

calo['ratit']=fuzz.trimf(calo.universe,[0,0,300])
calo['it']=fuzz.trimf(calo.universe,[0,300,700])
calo['TB']=fuzz.trimf(calo.universe,[300,700,1000])
calo['nhieu']=fuzz.trimf(calo.universe,[700,1000,1300])
calo['ratnhieu']=fuzz.trimf(calo.universe,[1300,1700,1700])

rule1 = ctrl.Rule(chieucao['cao'] & cannang['nhe'] & gioitinh['nu'] & tuoi['thanhnien'], calo['nhieu'])
rule2 = ctrl.Rule(chieucao['cao'] & cannang['TB'] & gioitinh['nu'] & tuoi['thanhnien'], calo['TB'])
rule3 = ctrl.Rule(chieucao['cao'] & cannang['nang'] & gioitinh['nu'] & tuoi['thanhnien'], calo['ratit'])
rule4 = ctrl.Rule(chieucao['thap'] & cannang['nhe'] & gioitinh['nu'] & tuoi['thanhnien'], calo['nhieu'])
rule5 = ctrl.Rule(chieucao['thap'] & cannang['TB'] & gioitinh['nu'] & tuoi['thanhnien'], calo['TB'])

rule6 = ctrl.Rule(chieucao['thap'] & cannang['nang'] & gioitinh['nu'] & tuoi['thanhnien'], calo['ratit'])
rule7 = ctrl.Rule(chieucao['thap'] & cannang['nhe'] & gioitinh['nu'] & tuoi['trungnien'], calo['nhieu'])
rule8 = ctrl.Rule(chieucao['thap'] & cannang['TB'] & gioitinh['nu'] & tuoi['trungnien'], calo['TB'])
rule9 = ctrl.Rule(chieucao['thap'] & cannang['nang'] & gioitinh['nu'] & tuoi['trungnien'], calo['ratit'])
rule10 = ctrl.Rule(chieucao['thap'] & cannang['nhe'] & gioitinh['nu'] & tuoi['caonien'], calo['nhieu'])

rule11 =  ctrl.Rule(chieucao['thap'] & cannang['TB'] & gioitinh['nu'] & tuoi['caonien'], calo['TB'])
rule12 =  ctrl.Rule(chieucao['thap'] & cannang['nang'] & gioitinh['nu'] & tuoi['caonien'], calo['it'])
rule13 = ctrl.Rule(chieucao['thap'] & cannang['TB'] & gioitinh['nam'] & tuoi['trungnien'], calo['TB'])
rule14 = ctrl.Rule(chieucao['thap'] & cannang['nang'] & gioitinh['nam'] & tuoi['trungnien'], calo['ratit'])
rule15 = ctrl.Rule(chieucao['thap'] & cannang['nhe'] & gioitinh['nam'] & tuoi['caonien'], calo['nhieu'])

rule16 =  ctrl.Rule(chieucao['thap'] & cannang['TB'] & gioitinh['nam'] & tuoi['caonien'], calo['TB'])
rule17 =  ctrl.Rule(chieucao['thap'] & cannang['nang'] & gioitinh['nam'] & tuoi['caonien'], calo['it'])
rule18 = ctrl.Rule(chieucao['cao'] & cannang['nang'] & gioitinh['nam'] & tuoi['thanhnien'], calo['ratit'])
rule19 = ctrl.Rule(chieucao['cao'] & cannang['nhe'] & gioitinh['nam'] & tuoi['trungnien'], calo['nhieu'])
rule20 = ctrl.Rule(chieucao['cao'] & cannang['TB'] & gioitinh['nam'] & tuoi['trungnien'], calo['TB'])

rule21 = ctrl.Rule(chieucao['cao'] & cannang['nang'] & gioitinh['nam'] & tuoi['trungnien'], calo['ratit'])
rule22 = ctrl.Rule(chieucao['cao'] & cannang['nhe'] & gioitinh['nam'] & tuoi['caonien'], calo['nhieu'])
rule23 = ctrl.Rule(chieucao['cao'] & cannang['TB'] & gioitinh['nam'] & tuoi['caonien'], calo['TB'])
rule24 = ctrl.Rule(chieucao['cao'] & cannang['nang'] & gioitinh['nam'] & tuoi['caonien'], calo['it'])
rule25 = ctrl.Rule(chieucao['thap'] & cannang['nhe'] & gioitinh['nam'] & tuoi['thanhnien'], calo['nhieu'])

rule26 = ctrl.Rule(chieucao['thap'] & cannang['TB'] & gioitinh['nam'] & tuoi['thanhnien'], calo['TB'])
rule27 = ctrl.Rule(chieucao['thap'] & cannang['nang'] & gioitinh['nam'] & tuoi['thanhnien'], calo['ratit'])
rule28 = ctrl.Rule(chieucao['thap'] & cannang['nhe'] & gioitinh['nam'] & tuoi['trungnien'], calo['nhieu'])
rule29 = ctrl.Rule(chieucao['TB'] & cannang['nhe'] & gioitinh['nam'] & tuoi['trungnien'], calo['nhieu'])
rule30 = ctrl.Rule(chieucao['TB'] & cannang['TB'] & gioitinh['nam'] & tuoi['trungnien'], calo['TB'])

rule31 = ctrl.Rule(chieucao['TB'] & cannang['nang'] & gioitinh['nam'] & tuoi['trungnien'], calo['it'])
rule32 = ctrl.Rule(chieucao['TB'] & cannang['nhe'] & gioitinh['nam'] & tuoi['caonien'], calo['nhieu'])
rule33 = ctrl.Rule(chieucao['TB'] & cannang['TB'] & gioitinh['nam'] & tuoi['caonien'], calo['TB'])
rule34 = ctrl.Rule(chieucao['TB'] & cannang['nang'] & gioitinh['nam'] & tuoi['caonien'], calo['it'])
rule35 = ctrl.Rule(chieucao['TB'] & cannang['nhe'] & gioitinh['nu'] & tuoi['thanhnien'], calo['nhieu'])

rule36 = ctrl.Rule(chieucao['TB'] & cannang['TB'] & gioitinh['nu'] & tuoi['thanhnien'], calo['TB'])
rule37 = ctrl.Rule(chieucao['TB'] & cannang['nang'] & gioitinh['nu'] & tuoi['thanhnien'], calo['ratit'])
rule38 = ctrl.Rule(chieucao['TB'] & cannang['TB'] & gioitinh['nu'] & tuoi['caonien'], calo['TB'])
rule39 = ctrl.Rule(chieucao['TB'] & cannang['nang'] & gioitinh['nu'] & tuoi['caonien'], calo['it'])
rule40 = ctrl.Rule(chieucao['TB'] & cannang['nhe'] & gioitinh['nam'] & tuoi['thanhnien'], calo['nhieu'])

rule41 = ctrl.Rule(chieucao['TB'] & cannang['TB'] & gioitinh['nam'] & tuoi['thanhnien'], calo['TB'])
rule42 = ctrl.Rule(chieucao['TB'] & cannang['nang'] & gioitinh['nam'] & tuoi['thanhnien'], calo['ratit'])
rule43 = ctrl.Rule(chieucao['cao'] & cannang['nhe'] & gioitinh['nam'] & tuoi['thanhnien'], calo['nhieu'])
rule44 = ctrl.Rule(chieucao['cao'] & cannang['TB'] & gioitinh['nam'] & tuoi['thanhnien'], calo['TB'])
rule45 = ctrl.Rule(chieucao['TB'] & cannang['nhe'] & gioitinh['nu'] & tuoi['trungnien'], calo['nhieu'])

rule46 = ctrl.Rule(chieucao['TB'] & cannang['TB'] & gioitinh['nu'] & tuoi['trungnien'], calo['TB'])
rule47 = ctrl.Rule(chieucao['TB'] & cannang['nang'] & gioitinh['nu'] & tuoi['trungnien'], calo['it'])
rule48 = ctrl.Rule(chieucao['TB'] & cannang['nhe'] & gioitinh['nu'] & tuoi['caonien'], calo['nhieu'])

CALO_ctrl = ctrl.ControlSystem([rule1, rule2, rule3, rule4, rule5, rule6, rule7, rule8, rule9,rule10,rule11,rule12,rule13,rule14,rule15,rule16,rule17,rule18,rule19,rule20,rule21,rule22,rule23,rule24,rule25,rule26,rule27,rule28,rule29,rule30,rule31,rule32,rule33,rule34,rule35,rule36,rule37,rule38,rule39,rule40,rule41,rule42,rule43,rule44,rule45,rule46,rule47,rule48])
CALO = ctrl.ControlSystemSimulation(CALO_ctrl)
CALO.input['chieucao'] = 175
CALO.input['cannang'] = 35
CALO.input['tuoi'] = 20
CALO.input['gioitinh'] = 2
CALO.compute()
print (CALO.output['calo'])
calo.view(sim=CALO)
# Out:
# 769.96996996997

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv('Salary_Data.csv')
x=data.drop(['Salary'], axis=True)
y=data['Salary']
print(y)
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv('Salary_Data.csv')
x=data.drop(['Salary'], axis=True)
y=data['Salary']
data.head()
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=42)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
sns.pairplot(data)
#data.shape

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv('Salary_Data.csv')
x=data.drop(['Salary'], axis=True)
y=data['Salary']
data.head()
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=42)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
sns.pairplot(data)
plt.plot(x_train,y_train,'r.',label='Train Data')
plt.xlabel('year experience')
plt.ylabel('Salary')
plt.legend()
plt.show()
#data.shape

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test).round(1)
cal=pd.DataFrame(np.c_[y_test,y_pred],columns=['Original Salary','Predicted Salary'])
print('Coeffient',model.coef_)
print('Intercept',model.intercept_)
print('Accuracy',model.score(x_test,y_test))
# Out:
# Coeffient [9423.81532303]
# Intercept 25321.583011776813
# Accuracy 0.9024461774180497

# %%
plt.scatter(x_train,y_train, color = 'red')
plt.plot(x_train,model.predict(x_train), color = 'blue')
plt.title('Salary vs Experience(Train set)')
plt.xlabel('Year of Experience')
plt.ylabel('Salary')
plt.show()
