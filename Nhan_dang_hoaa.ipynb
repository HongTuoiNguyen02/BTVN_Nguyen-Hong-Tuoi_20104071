# %% [markdown]
# <a href="https://colab.research.google.com/github/HongTuoiNguyen02/BTVN_Nguyen-Hong-Tuoi_20104071/blob/main/Nhan_dang_hoaa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from sklearn.utils import validation
from keras.preprocessing.image import ImageDataGenerator
from sklearn import preprocessing
from keras.utils import to_categorical
from keras.models import load_model
from keras.utils import load_img, img_to_array
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/BTVN/Flowers/
# Out:
# /content/drive/MyDrive/Colab Notebooks/BTVN/Flowers

# %%
train_data = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
train_set = train_data.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/BTVN/Flowers/Train',target_size=(300,300), batch_size=32, class_mode='categorical')
# Out:
# Found 176 images belonging to 3 classes.

# %%
test_set = train_data.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/BTVN/Flowers/Test',target_size=(300,300), batch_size=32, class_mode='categorical')
# Out:
# Found 25 images belonging to 3 classes.

# %%
train_set.class_indices
# Out:
# {'Cuc': 0, 'Hong': 1, 'Mai': 2}

# %%
test_set.class_indices
# Out:
# {'Cuc': 0, 'Hong': 1, 'Mai': 2}

# %%
model=Sequential()
model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(300,300,3))) 
model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(300,300,3))) 
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(300,300,3))) 
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
model.add(Dropout(0.2))
model.add(Dense(3,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 300, 300, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 300, 300, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 150, 150, 32)     0
#  )
#
#  conv2d_2 (Conv2D)           (None, 150, 150, 64)      18496
#
#  conv2d_3 (Conv2D)           (None, 150, 150, 64)      36928
#
#  max_pooling2d_1 (MaxPooling  (None, 75, 75, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 75, 75, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 75, 75, 128)       147584
#
#  max_pooling2d_2 (MaxPooling  (None, 37, 37, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 175232)            0
#
#  dense (Dense)               (None, 128)               22429824
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 22,717,219
# Trainable params: 22,717,219
# Non-trainable params: 0
# _________________________________________________________________

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Biên dịch 
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(train_set,epochs=100,batch_size=128,verbose=1, validation_data=test_set, callbacks=[EarlyStopping(monitor='val_loss', patience=20)])
# Out:
# Epoch 1/100
# 6/6 [==============================] - 119s 17s/step - loss: 41.2199 - accuracy: 0.3864 - val_loss: 4.4336 - val_accuracy: 0.4000
# Epoch 2/100
# 6/6 [==============================] - 76s 12s/step - loss: 2.1078 - accuracy: 0.5341 - val_loss: 0.4410 - val_accuracy: 0.7600
# Epoch 3/100
# 6/6 [==============================] - 76s 14s/step - loss: 0.5872 - accuracy: 0.7614 - val_loss: 0.3294 - val_accuracy: 0.8800
# Epoch 4/100
# 6/6 [==============================] - 75s 12s/step - loss: 0.2945 - accuracy: 0.8920 - val_loss: 0.1507 - val_accuracy: 0.9200
# Epoch 5/100
# 6/6 [==============================] - 77s 13s/step - loss: 0.1256 - accuracy: 0.9375 - val_loss: 0.0246 - val_accuracy: 1.0000
# Epoch 6/100
# 6/6 [==============================] - 76s 12s/step - loss: 0.0837 - accuracy: 0.9602 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 7/100
# 6/6 [==============================] - 75s 14s/step - loss: 0.0482 - accuracy: 0.9886 - val_loss: 0.0431 - val_accuracy: 1.0000
# Epoch 8/100
# 6/6 [==============================] - 75s 12s/step - loss: 0.0975 - accuracy: 0.9602 - val_loss: 0.0229 - val_accuracy: 1.0000
# Epoch 9/100
# 6/6 [==============================] - 75s 14s/step - loss: 0.0815 - accuracy: 0.9659 - val_loss: 0.0191 - val_accuracy: 1.0000
# Epoch 10/100
# 6/6 [==============================] - 76s 12s/step - loss: 0.0349 - accuracy: 0.9943 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 11/100
# 6/6 [==============================] - 76s 12s/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 4.0270e-04 - val_accuracy: 1.0000
# Epoch 12/100
#
-04 - val_accuracy: 1.0000
# Epoch 42/100
# 6/6 [==============================] - 77s 12s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 2.0504e-07 - val_accuracy: 1.0000
# Epoch 43/100
# 6/6 [==============================] - 76s 12s/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.1199e-05 - val_accuracy: 1.0000
# Epoch 44/100
# 6/6 [==============================] - 76s 12s/step - loss: 1.2086e-04 - accuracy: 1.0000 - val_loss: 3.7048e-04 - val_accuracy: 1.0000
# Epoch 45/100
# 6/6 [==============================] - 80s 13s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 3.7992e-04 - val_accuracy: 1.0000
# Epoch 46/100
# 6/6 [==============================] - 77s 13s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 2.7238e-05 - val_accuracy: 1.0000
# Epoch 47/100
# 6/6 [==============================] - 77s 14s/step - loss: 5.2442e-05 - accuracy: 1.0000 - val_loss: 2.5224e-06 - val_accuracy: 1.0000
# Epoch 48/100
# 6/6 [==============================] - 77s 13s/step - loss: 6.8109e-04 - accuracy: 1.0000 - val_loss: 7.0095e-07 - val_accuracy: 1.0000
# Epoch 49/100
# 6/6 [==============================] - 77s 13s/step - loss: 1.1824e-05 - accuracy: 1.0000 - val_loss: 1.6212e-07 - val_accuracy: 1.0000
# Epoch 50/100
# 6/6 [==============================] - 77s 12s/step - loss: 5.4659e-05 - accuracy: 1.0000 - val_loss: 4.7684e-08 - val_accuracy: 1.0000
# Epoch 51/100
# 6/6 [==============================] - 76s 12s/step - loss: 2.9420e-06 - accuracy: 1.0000 - val_loss: 1.9073e-08 - val_accuracy: 1.0000
# Epoch 52/100
# 6/6 [==============================] - 77s 12s/step - loss: 4.6901e-05 - accuracy: 1.0000 - val_loss: 2.3842e-08 - val_accuracy: 1.0000
# Epoch 53/100
# 6/6 [==============================] - 76s 12s/step - loss: 5.4050e-07 - accuracy: 1.0000 - val_loss: 1.9073e-08 - val_accuracy: 1.0000
# Epoch 54/100
# 6/6 [==============================] - 76s 12s/step - loss: 7.3255e-05 - accuracy: 1.0000 - val_loss: 1.2875e-07 - val_accuracy: 1.0000
# Epoch 55/100
# 6/6 [==============================] - 76s 12s/step - loss: 5.4021e-06 - accuracy: 1.0000 - val_loss: 2.8610e-08 - val_accuracy: 1.0000
# Epoch 56/100
# 6/6 [==============================] - 76s 12s/step - loss: 2.2925e-06 - accuracy: 1.0000 - val_loss: 9.5367e-09 - val_accuracy: 1.0000

# %%
model.save('/content/drive/MyDrive/Colab Notebooks/BTVN/Flowers/Nhan_dang_hoa.h5')

# %%
model_hoa = load_model('/content/drive/MyDrive/Colab Notebooks/BTVN/Flowers/Nhan_dang_hoa.h5')

# %%
Score=model.evaluate(train_set,verbose=0)
print('Train Loss', Score[0])
print('Train Accuracy', Score[1])
# Out:
# Train Loss 3.6972298858017894e-06
# Train Accuracy 1.0

# %%
test='/content/drive/MyDrive/Colab Notebooks/BTVN/Flowers/Validation'
for i in os.listdir(test):
  img=load_img(test+'/'+i,target_size=(300,300))
  plt.imshow(img)
  img=img_to_array(img)
  img=img.astype('float32')
  img=img/255
  img=np.expand_dims(img,axis=0)
  result=model_hoa.predict(img)
  if round(result[0][0])==1:
    prediction='Cuc'
  if round(result[0][1])==1:
    prediction = 'Hong'
  if round(result[0][2])==1:
    prediction='Mai'
  print(prediction)
  plt.show()
# Out:
# 1/1 [==============================] - 0s 254ms/step
# Mai
# 1/1 [==============================] - 0s 130ms/step
# Mai
# 1/1 [==============================] - 0s 129ms/step
# Mai
# 1/1 [==============================] - 0s 130ms/step
# Cuc
# 1/1 [==============================] - 0s 136ms/step
# Cuc
# 1/1 [==============================] - 0s 129ms/step
# Cuc
# 1/1 [==============================] - 0s 129ms/step
# Hong
# 1/1 [==============================] - 0s 130ms/step
# Hong
# 1/1 [==============================] - 0s 132ms/step
# Hong
