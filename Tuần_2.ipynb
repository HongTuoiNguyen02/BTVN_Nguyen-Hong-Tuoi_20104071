# %% [markdown]
# <a href="https://colab.research.google.com/github/HongTuoiNguyen02/BTVN_Nguyen-Hong-Tuoi_20104071/blob/main/Tu%E1%BA%A7n_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from openpyxl import Workbook
wb = Workbook()
sheet = wb.active
sheet ['A1']='Nguyen van A'
sheet ['B1']='20104001'
sheet ['A2']='Le Thi B'
sheet ['B2']='20104002'
wb.save('test.xlsx')

# %%
import openpyxl
wb = openpyxl.load_workbook('test.xlsx')
sheet = wb.active
t1 = sheet['A1']
t2 = sheet['B1']
t3 = sheet.cell(row=2, column=1)
t4 = sheet.cell(row=2, column=2)
print (t1.value, t2.value)
print (t3.value, t4.value)
# Out:
# Nguyen van A 20104001
# Le Thi B 20104002

# %%
import openpyxl
my_wb = openpyxl.Workbook()
my_sheet = my_wb.active
c1 = my_sheet.cell(row = 1, column = 1)
c1.value = "Nguyen Hong Tuoi"
c2 = my_sheet.cell(row=1, column = 2)
c2.value = "Cam Tu Dao"
c3 = my_sheet['A2']
c3.value = "Ulsan"
c4 = my_sheet['B2']
c4.value = "Genovoa"
my_wb.save('Thu Duc.xlsx')

# %%
import openpyxl
my_wb = openpyxl.Workbook()
my_sheet = my_wb.active
my_wb.create_sheet(index = 1, title = "KCN")
my_wb.save('KTX.xlsx')

# %%
import openpyxl
my_path = "Thu Duc.xlsx"
my_wb_obj = openpyxl.load_workbook(my_path)
my_sheet_obj = my_wb_obj.active
print(my_sheet_obj.max_row)
# Out:
# 2

# %%
import openpyxl
my_path = "test.xlsx"
My_wb_obj = openpyxl.load_workbook(my_path)
sheet_obj = my_wb_obj.active
print(my_sheet_obj.max_column)
# Out:
# 2

# %%
my_wb_obj = openpyxl.load_workbook('test.xlsx')
my_sheet_obj = my_wb_obj.active
my_row = my_sheet_obj.max_row
for i in range(1, my_row + 1):
 cell_obj = my_sheet_obj.cell(row = i, column = 1)
 print(cell_obj.value)
# Out:
# Nguyen van A
# Le Thi B

# %%
my_wb_obj = openpyxl.load_workbook('test.xlsx')
my_sheet_obj = my_wb_obj.active
my_max_col = my_sheet_obj.max_column
for i in range(1, my_max_col + 1):
 cell_obj = my_sheet_obj.cell(row = 2, column = i)
 print(cell_obj.value, end = " ")
# Out:
# Le Thi B 20104002

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(6)
y = x + 1
plt.plot(x,y, 'o--')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(6)
y = x + 1
plt.plot(x,y, 'o--')
plt.plot(x,-y, 'o--')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(6)
y = x + 1
plt.plot(x,y, 'o--')
plt.plot(x,-y, 'o--')
plt. title('y=x và y=-x')
plt.xlabel('x')
plt.ylabel('y')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(6)
y = x + 1
plt.plot(x,y, 'o--')
plt.plot(x,-y, 'o--')
plt. title('y=x và y=-x')
plt.xlabel('x')
plt.ylabel('y')
plt.grid('on')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(6)
y = x + 1
plt.plot(x,y, 'o--')
plt.plot(x,-y, 'o--')
plt. title('y=x và y=-x')
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import matplotlib.pyplot as plt #chia theo số thập phânphân
import numpy as np
N=16
x=np.linspace(0,15,16)
y=x
plt.plot(x,y, 'o--')
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import matplotlib.pyplot as plt #chia theo số thập phânphân
import numpy as np
N=16
x=np.linspace(0,15,16)
y=np.logspace(0.1,2,16)
plt.plot(x,y,'--o')
plt.grid('on')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import matplotlib.pyplot as plt #chia theo số thập phânphân
import numpy as np
x=[4,5,3,1,6,7]
plt.plot(x)
plt.show()

# %%
import matplotlib.pyplot as plt #chia theo số thập phânphân
import numpy as np
x=np.arange(25)
plt.plot(x)
plt.show()

# %%
import matplotlib.pyplot as plt #chia theo số thập phânphân
import numpy as np
x=np.arange(25)
plt.plot(x,(x**3+1))
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import matplotlib.pyplot as plt #chia theo số thập phânphân
import numpy as np
x=np.arange(7)
plt.plot(x,-x**2)
plt.plot(x,-x**3)
plt.plot(x,-2*x)
plt.plot(x,-2**x)
#plt.plot(x,-x**2,x,-x**3,x,-2*x,x,-2**x)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x=np.arange(7)
plt.plot(x,-x**2,x,-x**3,x,-2*x,x,-2**x) #(,'-',)
plt.grid(True)
plt.savefig('hongtuoi.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import matplotlib.pyplot as plt #chia theo số thập phânphân
import numpy as np
x=np.arange(3)
plt.subplots_adjust(wspace=0.3,hspace=0.3)
plt.subplot(2,2,1)
plt.plot(x,-x**2, color='g')
plt.subplot(2,2,2)
plt.plot(x,-x**3, color='r')
plt.subplot(2,2,3)
plt.plot(x,-2*x,color='b')
plt.subplot(2,2,4)
plt.plot(x,-2**x,'o')
plt.show()

# %%
import matplotlib.pyplot as plt #chia theo số thập phânphân
import numpy as np
plt.axis([0,100,0,10])
plt. scatter(20,5,s=1000,color='black',alpha=1)
plt.scatter(60,5,s=1000, color='black',alpha=0.5)
plt.scatter(80,5, s=1000, color='black',alpha=0.1)
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np
plt.plot([2,4],[1,3], linewidth=5, color='r')
plt.text(5,7,'Text')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import matplotlib.pyplot as plt 
import numpy as np
plt.axis([0,20, 0,20])
plt.arrow(8,2,-6,5, head_length=4, head_width=2, color='g')

# %%
import matplotlib.pyplot as plt 
import numpy as np
x=np.arange(4)
y=np.random.rand()
plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np
x=np.arange(4)
y=np.random.rand()
plt.barh(x,y)
plt.show()

# %%
y=np.random.rand(3,4)
plt.bar(x+0,y[0], color='b',width=0.25)
plt.bar(x+0.25,y[1], color='y', width=0.25)
plt.bar(x+0.5,y[2], color='r', width=0.23)
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np
N=1000
x=np.random.rand(N)
y=np.random.rand(N)
color=np.random.rand(N)
size =20
plt.scatter(x,y,s=size,c=color,alpha=1)
plt.show()
